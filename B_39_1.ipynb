# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from ffpyplayer.player import MediaPlayer
import time

# %%
image=cv2.imread("My photo (2).jpg")

# %%
cv2.imshow("My photo (2)",image)
cv2.waitKey(10000)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cv2.imshow("My photo (2)",image)
#       2 cv2.waitKey(10000)
#       3 cv2.destroyAllWindows()
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
pip uninstall opencv-python

# %%
flags = [-1, 0,1, 2, 4, 8,16,17,32,33,64,65,128]
flag_status = ["UNCHANGED", "GRAYSCALE", "COLOR","ANYDEPTH","ANYCOLOUR","LOAD_GDAL","REDUCED_GRAYSCALE_2","REDUCED_COLOR_2","REDUCED_GRAYSCALE_4", "REDUCED_COLOUR_4","REDUCED_GRAYSCALE_8", "REDUCED_COLOUR_8","IGNORE_ORIENTATION"]

plt.figure(figsize=(20,20))

for flag in range(1, len(flags)):
    plt.subplot(4,4,flag)
    plt.axis('off')
    plt.title(f"{flags[flag-1]}-{flag_status[flag]}",{'fontsize':16, 'fontweight':'bold'})
    plt.imshow(cv2.cvtColor(cv2.imread("My photo (2).jpg", flags[flag-1]), cv2.COLOR_BGR2RGB))

# %%
image.shape
# Out:
# (3672, 3157, 3)

# %%
print(f"Height of image:{image.shape[0]}pixels")
print(f"Width of image:{image.shape[1]}pixels")
# Out:
# Height of image:3672pixels
# Width of image:3157pixels

# %%
def readImage(path):
    img=cv2.imread(path+"\\My photo (2).jpg")
    cv2.imshow("Image",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
cv2.imwrite("My photo (2)_Written.jpg",image)
# Out:
# True

# %%
def writeImage(path):
    img= cv2.imread(path + "\\My photo (2).jpg") 
    cv2.imwrite(path + "\\My photo (2)_written.jpg", img)
    cv2.imshow("Image written", img)
    cv2.waitKey(5000) 
    cv2.destroyAllWindows()

# %%
cap= cv2.VideoCapture("withoutaudio.mp4")

while True:

    ret, frame= cap.read()

    if ret == True:

        cv2.imshow("Output", frame) 
        
    if cv2.waitKey(25) == ord('q'):

        break
        

cap.release()

cv2.destroyAllwindows()

# %%
def readVideo(path):
    cap= cv2.VideoCapture(path +"\\withoutaudio.mp4")
    
    while True:

        ret, frame= cap.read()

        if ret == True:

            cv2.imshow("Output", frame) 
        
        if cv2.waitKey(25) == ord('q'):

            break

cap.release()

cv2.destroyAllwindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      12         if cv2.waitKey(25) == ord('q'):
#      14             break
# ---> 16 cap.release()
#      18 cv2.destroyAllwindows()
#
# NameError: name 'cap' is not defined

# %%
cap = cv2.VideoCapture ("video.mp4")
player = MediaPlayer("video.mp4")

while True:

    ret, frame = cap.read()

    if not ret:

        player = 0

        break

    audio_frame, val = player.get_frame()

    cv2.imshow("Output", frame)

    if cv2.waitKey(25) == ord('q'):

        player =0
        break

cap.release()

cv2.destroyAllWindows()

# %%
def readVideoWithAudio(path):
    cap = cv2.VideoCapture (path + "\\video.mp4")
    player = MediaPlayer(path +"\\video.mp4")

    while True:

        ret, frame = cap.read()

        if not ret:

            player = 0

            break

        audio_frame, val = player.get_frame()

        cv2.imshow("Output", frame)

        if cv2.waitKey(25) == ord('q'):

            player = 0 
            break

cap.release()

cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(2)

frame_width = int(cap.get(3))
frame_height = int(cap.get(4))

size = (frame_width, frame_height)

vid_writer = cv2.VideoWriter ('Recored.mp4', cv2.VideoWriter_fourcc(*'DIVX'), 12, size)

while True:

    ret, frame = cap.read()

    if ret: 
        vid_writer.write(frame) 
        cv2.imshow("Frame", frame)

        if cv2.waitKey(1) & 0xFF== ord('q'): break

    else: 
        break

cap.release() 
vid_writer.release()

cv2.destroyAllWindows()

print("The video was successfully saved")
